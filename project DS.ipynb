# %%
import pandas as pd
import numpy as nb
t = pd.read_csv("train.csv")

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
t.drop("Cabin",axis = 1,inplace = True)
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
t.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
t.Sex=nb.where(t.Sex.str.contains("female"),0,1)
t.head(25)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
#
# ...

# %%
t["first name"]= t["Name"].str.split(",").str[1]
t["surname"]= t["Name"].str.split(",").str[0]
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked  \
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S
#
# ...

# %%
t.drop("Name",axis=1,inplace=True)
t.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1         0       3    1  22.0      1      0         A/5 21171
# 1            2         1       1    0  38.0      1      0          PC 17599
# 2            3         1       3    0  26.0      0      0  STON/O2. 3101282
# 3            4         1       1    0  35.0      1      0            113803
# 4            5         0       3    1  35.0      0      0            373450
#
#       Fare Embarked                                   first name    surname
# 0   7.2500        S                              Mr. Owen Harris     Braund
# 1  71.2833        C   Mrs. John Bradley (Florence Briggs Thayer)    Cumings
# 2   7.9250        S                                  Miss. Laina  Heikkinen
# 3  53.1000        S           Mrs. Jacques Heath (Lily May Peel)   Futrelle
# 4   8.0500        S                            Mr. William Henry      Allen

# %%
t.Age.sort_values(ascending=False).sum
# Out:
# <bound method Series.sum of 630    80.0
# 851    74.0
# 96     71.0
# 493    71.0
# 116    70.5
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: Age, Length: 891, dtype: float64>

# %%
t.Age.fillna(t.Age.mean(), inplace = True)
t.Age =t.Age.astype(int)
t
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0              1         0       3    1   22      1      0         A/5 21171
# 1              2         1       1    0   38      1      0          PC 17599
# 2              3         1       3    0   26      0      0  STON/O2. 3101282
# 3              4         1       1    0   35      1      0            113803
# 4              5         0       3    1   35      0      0            373450
# ..           ...       ...     ...  ...  ...    ...    ...               ...
# 886          887         0       2    1   27      0      0            211536
# 887          888         1       1    0   19      0      0            112053
# 888          889         0       3    0   29      1      2        W./C. 6607
# 889          890         1       1    1   26      0      0            111369
# 890          891         0       3    1   32      0      0            370376
#
# ...

# %%
Q1 = t.quantile(0.25)
Q3 = t.quantile(0.75)
IQR = Q3-Q1
Upper_fence = Q3+(IQR*1.5)
print(Upper_fence)
print(Upper_fence.iloc[4])
t=t.query('Age < 64.8125 & SibSp < 4 & Fare < 100' )
t.describe
# Out:
# PassengerId    1336.0000
# Survived          2.5000
# Pclass            4.5000
# Sex               2.5000
# Age              54.5000
# SibSp             2.5000
# Parch             0.0000
# Fare             65.6344
# dtype: float64
# 54.5
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0              1         0       3    1   22      1      0         A/5 21171
# 1              2         1       1    0   38      1      0          PC 17599
# 2              3         1       3    0   26      0      0  STON/O2. 3101282
# 3              4         1       1    0   35      1      0            113803
# 4              5         0       3    1   35      0      0            373450
# ..           ...       ...     ...  ...  ...    ...    ...               ...
# 886          887         0       2    1   27      0      0            211536
# 887          888         1       1    0   19      0      0            112053
# ...

# %%
t.shape
# Out:
# (797, 12)

# %%
t.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   797.000000  797.000000  797.000000  797.000000  797.000000
# mean    447.627353    0.375157    2.377666    0.661230   29.483061
# std     258.116458    0.484467    0.793601    0.473589   11.806385
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     222.000000    0.000000    2.000000    0.000000   23.000000
# 50%     451.000000    0.000000    3.000000    1.000000   29.000000
# 75%     667.000000    1.000000    3.000000    1.000000   35.000000
# max     891.000000    1.000000    3.000000    1.000000   64.000000
#
#             SibSp       Parch        Fare
# count  797.000000  797.000000  797.000000
# mean     0.347553    0.301129   21.541399
# std      0.622775    0.751656   20.532545
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.895800
# 50%      0.000000    0.000000   13.000000
# 75%      1.000000    0.000000   26.287500
# ...

# %%
t.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# first name     0
# surname        0
# dtype: int64

# %%
t.dropna(inplace = True)
# Out:
# C:\Users\EGYPT_LAPTOP\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
t.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# first name     0
# surname        0
# dtype: int64

# %%
t.shape
# Out:
# (795, 12)
